# %%
import matplotlib.pyplot as plt

methods = ['Nurual Matrix Factorization CF', 'Matrix Factorization SVD', 'User-Based CF', 'Item-based CF']
rmse = [0.15799635957841116, 0.25022, 0.9465967397892301, 0.9465967397892301]

# Create the bar plot
plt.figure(figsize=(10, 6))
plt.bar(methods, rmse, width=0.4, color= ['red', 'green', 'blue', 'darkblue'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xlabel("Methods")
plt.ylabel("RMSE")
plt.title("5 Fold Corss Validation RMSE Comparison of Collaborative Filtering Methods")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()
